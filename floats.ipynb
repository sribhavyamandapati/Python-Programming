# %%
x=1.1
y=1.5
z=-3.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=54e5
y=21E5
z=-87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=6+8j
y=9j
z=-3j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=2
y=2.4
z=3j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)


print(type(a))
print(type(b))
print(type(c))
# Out:
# 2.0
# 2
# (2+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
x= int(3)
y=int(5.8)
z=int("7")
print(x)
print(y)
print(z)
# Out:
# 3
# 5
# 7

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0
