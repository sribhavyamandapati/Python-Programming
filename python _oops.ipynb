# %%
class CSE:
  john=10
  peter=20
anil=CSE()
print(anil.john * anil.peter)
# Out:
# 200

# %%
class MECH:
  s=5
suresh=MECH()
print(suresh.s*suresh.s)
# Out:
# 25

# %%
class MECH:
  s=5
suresh=MECH()
print(suresh.t *suresh.t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_965/161663235.py in <cell line: 0>()
#       2   s=5
#       3 suresh=MECH()
# ----> 4 print(suresh.t *suresh.t)
#
# AttributeError: 'MECH' object has no attribute 't'

# %%
class ECE:
  john=20
  peter=30
anil=ECE()
print(anil.john*anil.peter)
# Out:
# 600

# %%
class ECE:
  john=20
  peter=30
print(ECE.john*ECE.peter)
# Out:
# 600

# %%
class CSE:
  pass
anil=CSE()
anil.lily=10
anil.lila=20
print(anil.lily*anil.lila)
# Out:
# 200

# %%
class ECE:
  pass
ECE.lila=20
ECE.lily=10
print(ECE.lila*ECE.lily)
# Out:
# 200

# %%
class MECH:
  f=10
  g=20
  def sharuk():
    print("good morning")
anil=MECH()
print(anil.f)
print(anil.g)
anil.sharuk()
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_965/1107750030.py in <cell line: 0>()
#       7 print(anil.f)
#       8 print(anil.g)
# ----> 9 anil.sharuk()
#
# TypeError: MECH.sharuk() takes 0 positional arguments but 1 was given

# %%
class MECH:
  f=10
  g=20
  def sharuk(self):
    print("good morning")
anil=MECH()
print(anil.f)
print(anil.g)
anil.sharuk()
# Out:
# 10
# 20
# good morning

# %%
class MECH:
  f=10
  g=20
  def sharuk(self):
    print("good morning",self.f)
anil=MECH()
print(anil.f)
print(anil.g)
anil.sharuk()
# Out:
# 10
# 20
# good morning 10

# %%
class ECE:
  j=10
  p=30
  def add(self):
    print(self.j+self.p)
  def sub(self):
    print(self.j-self.p)
kumar=ECE()
kumar.add()
kumar.sub()
# Out:
# 40
# -20

# %%
class PRIME_NUMBER:
  try:
    n=7
    def sharuk(self):
      t=0
      for i in range(1,self.n+1):
        if self.n%i==0:
          t=t+1
      if t==2:
        print(f"{self.n}:Is a prime number")
      else:
        print(f"{self.n}:Is not a prime number")
  except Exception as e:
    er_t,er_m,er_line=sys.exc_info()
    print(f"Error line number {er_line.tb_lineno} Due to:{er+t} reason:{er_m}")
a=PRIME_NUMBER()
a.sharuk()
# Out:
# 7:Is a prime number

# %%
n=8
s=0
for i in range(1,n):
  if n%i==0:
    s=s+i
if s==n:
  print(f"{n} is a perfect number")
else:
  print(f'{n} is not a perfect number')
# Out:
# 8 is not a perfect number

# %%
def perfect(n):
  s=0
  for i in range(1,n):
    if n%i==0:
      s=s+i
  if s==n:
    print(f"{n} is a perfect number")
  else:
    print(f'{n} is not a perfect number')
perfect(6)
# Out:
# 6 is a perfect number

# %%
import sys

# %%
try:
  def perfect(n):
    s=0
    for i in range(1,n):
      if n%i==0:
        s=s+i
    if s==n:
      print(f"{n} is a perfect number")
    else:
      print(f'{n} is not a perfect number')
  perfect(k)
except Exception as e:
  er_t,er_m,er_line=sys.exc_info()
  print(f"Error line number {er_line.tb_lineno} Due to: {er_t} Reason: {er_m}")
# Out:
# Error line number 11 Due to: <class 'NameError'> Reason: name 'k' is not defined

# %%
class PERFECT:
  try:
    def perfect(self,n):
      s=0
      for i in range(1,n):
        if n%i==0:
          s=s+i
      if s==n:
        print(f"{n} is a perfect number")
      else:
        print(f'{n} is not a perfect number')


  except Exception as e:
    er_t,er_m,er_line=sys.exc_info()
    print(f"Error line number {er_line.tb_lineno} Due to: {er_t} Reason: {er_m}")


p=PERFECT()
p.perfect(5)
# Out:
# 5 is not a perfect number
