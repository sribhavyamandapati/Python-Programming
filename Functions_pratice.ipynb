# %%
n=2
for i in range(1,11):
  print(n,"*",i,"=",i*n)
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
n=3
for i in range(1,11):
  print(n,"*",i,"=",i*n)
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
def table(n):
  for i in range(1,11):
   print(n,"*",i,"=",i*n)
table(8)
# Out:
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 8 * 10 = 80

# %%
table(10)
# Out:
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90
# 10 * 10 = 100

# %%
def even(f):
  for i in f:
    if i%2==0:
      print(f"Even:{i}")

a=[10,11,12,13,14,15,16,17,18]
even(a)
# Out:
# Even:10
# Even:12
# Even:14
# Even:16
# Even:18

# %%
def kiran(a,b,c,d):
  print(a,b,c,d)
kiran(10,20,30,40)
# Out:
# 10 20 30 40

# %%
def kiran(*india):
  print(type(india))
  print(india[2])
kiran(10,20,30,40)
# Out:
# <class 'tuple'>
# 30

# %%
def sharuk(*india):
  for i in india:
    if i%2==0:
      print(f"even:{i}")


sharuk(10,11,12,13,14)
# Out:
# even:10
# even:12
# even:14

# %%
def kiran(a):
  for i in a:
    print(a[i]+100)
fruits={"apple":100,"banana":200,"carrot":300}
kiran(fruits)
# Out:
# 200
# 300
# 400

# %%
def kiran(**kumar):
  print(kumar)


kiran(india =100,paris =300)
# Out:
# {'india': 100, 'paris': 300}

# %%
def kiran(a,b):
  for i in range(a,b):
    if i%2==0:
      print(f"even:{i}")

kiran(10,20)
# Out:
# even:10
# even:12
# even:14
# even:16
# even:18

# %%
def kiran(a,b):
  for i in range(a,b):
    if i%2==0:
      return f"Even:{i}"

a=kiran(10,20)
print(a)
# Out:
# Even:10

# %%
def kiran(a,b):
  c=[]
  for i in range(a,b):
    if i%2==0:
      c.append(i)
  return c



a=kiran(10,20)
print(a)
# Out:
# [10, 12, 14, 16, 18]
