# %%
x=8
y=9
print(x+y)
# Out:
# 17

# %%
x=88
y=90
print(x-y)
# Out:
# -2

# %%
x=4
y=8
print(x*y)
# Out:
# 32

# %%
x=56
y=89
print(x/y)
# Out:
# 0.6292134831460674

# %%
x=7
y=9
print(x%y)
# Out:
# 7

# %%
x=2
y=5
print(x**y)
# Out:
# 32

# %%
x=11
y=3
print(x//y)
# Out:
# 3

# %%
x=4
print(x)
# Out:
# 4

# %%
x=7
x+=4
print(x)
# Out:
# 11

# %%
x=6
x-=9
print(x)
# Out:
# -3

# %%
x=5
x*=3
print(x)
# Out:
# 15

# %%
x=60
x/=78
print(x)
# Out:
# 0.7692307692307693

# %%
x=5
x%=3
print(x)
# Out:
# 2

# %%
x=7
x//=6
print(x)
# Out:
# 1

# %%
x=4
x**=9
print(x)
# Out:
# 262144

# %%
x=24
x//=9
print(x)
# Out:
# 2

# %%
x=4
y=8
print(x==y)
# Out:
# False

# %%
x=6
y=9
print(x!=y)
# Out:
# True

# %%
x=8
y=9
print(x<y)
# Out:
# True

# %%
x=4
y=9
print(x<y)
# Out:
# True

# %%
x=9
y=3
print(x>=y)
# Out:
# True

# %%
x=6
y=9
print(x<=y)
# Out:
# True

# %%
x=9
y=12
print(x>3 and y>10)
# Out:
# True

# %%
x=7
print(x>3 or x<4)
# Out:
# True

# %%
x=12
print(not(x>3 and x<10))
# Out:
# True

# %%
x=["python","datascience","machine learning"]
y=["python","datascience"]
z=x
print(x is z)
print(x is y)
print(x==y)
# Out:
# True
# False
# False

# %%
a=["Artificial intelligence","machine learning"]
b=["Artificial intelligence","machine learning"]
a=b

print(a is not b)
print(a is not b)
print(a!=b)
# Out:
# False
# False
# False

# %%
x=["python","cloud"]
print("cloud" in x)
# Out:
# True

# %%
x=["engineering","science"]
print("engineering" not in x)
# Out:
# False

# %%
"2" is "2"
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipykernel_2966/564064368.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   "2" is "2"
# True

# %%
"python" is "python"
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipykernel_2966/3585426024.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   "python" is "python"
# True

# %%
a,b=8,9
if a>b:
  print("a")
else:
  print("b")
# Out:
# b

# %%
a,b=7,9
print("a" if a>b else "b")
# Out:
# b

# %%
a,b=10,20
min=a if a<b else b
print(min)
# Out:
# 10

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(3)
# Out:
# '0b11'

# %%
bin(9)
# Out:
# '0b1001'

# %%
True/2
# Out:
# 0.5

# %%
False*2
# Out:
# 0

# %%
bin(4)
bin(8)
4 & 8
# Out:
# 0

# %%
False & True
# Out:
# False

# %%
1&True
# Out:
# 1

# %%
1.0 & 1.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2966/3263165722.py in <cell line: 0>()
# ----> 1 1.0 & 1.0
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'

# %%
0b110 & 0b101
# Out:
# 4

# %%
6|1
# Out:
# 7

# %%
0b110|0b101
# Out:
# 7

# %%
bin(7)
# Out:
# '0b111'

# %%
True|False
# Out:
# True

# %%
6^6
# Out:
# 0

# %%
6^0
# Out:
# 6

# %%
6^3
# Out:
# 5
