# %%
print"sam")
# Out:
#   File "/tmp/ipykernel_5267/1942287416.py", line 1
#     print"sam")
#               ^
# SyntaxError: unmatched ')'

# %%
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5267/302864193.py in <cell line: 0>()
# ----> 1 print(num)
#
# NameError: name 'num' is not defined

# %%
mylist=[1,2,3,4]
print(mylist[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5267/1822032217.py in <cell line: 0>()
#       1 mylist=[1,2,3,4]
# ----> 2 print(mylist[10])
#
# IndexError: list index out of range

# %%
mydict={1:"a",2:"b",3:"c"}
print(mydict[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5267/4113442706.py in <cell line: 0>()
#       1 mydict={1:"a",2:"b",3:"c"}
# ----> 2 print(mydict[4])
#
# KeyError: 4

# %%
if 4<3:
print("4 is greater than 3")
# Out:
#   File "/tmp/ipykernel_5267/1518193168.py", line 2
#     print("4 is greater than 3")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a=0
b=10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_5267/2621364788.py in <cell line: 0>()
#       1 a=0
# ----> 2 b=10/0
#
# ZeroDivisionError: division by zero

# %%
a=int("sam")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5267/4223199357.py in <cell line: 0>()
# ----> 1 a=int("sam")
#
# ValueError: invalid literal for int() with base 10: 'sam'

# %%
num1=input("please enter a number:")
num2=int(num1)
print(num2)
# Out:
# please enter a number:2222ef
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5267/4016863072.py in <cell line: 0>()
#       1 num1=input("please enter a number:")
# ----> 2 num2=int(num1)
#       3 print(num2)
#
# ValueError: invalid literal for int() with base 10: '2222ef'

# %% [markdown]
# **1.zero Division Error**

# %%
a=10
b=a/0
print(b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_5267/3208630485.py in <cell line: 0>()
#       1 a=10
# ----> 2 b=a/0
#       3 print(b)
#
# ZeroDivisionError: division by zero

# %%
a=int(input("Enter a Number="))
b=int(input("enter a number for b= "))
c=a/b
print(c)
# Out:
# Enter a Number=4
# enter a number for b= 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_5267/3662644785.py in <cell line: 0>()
#       1 a=int(input("Enter a Number="))
#       2 b=int(input("enter a number for b= "))
# ----> 3 c=a/b
#       4 print(c)
#
# ZeroDivisionError: division by zero

# %%
a='4'
b=int(a)
print(b)
# Out:
# 4

# %%
a=4
c= str(a)
print(c)
# Out:
# 4

# %%
a="k"
b=int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5267/3613379728.py in <cell line: 0>()
#       1 a="k"
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'k'

# %%
a="kamal"
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5267/232722622.py in <cell line: 0>()
#       1 a="kamal"
# ----> 2 print(l)
#
# NameError: name 'l' is not defined

# %%
name="python"
print(neme1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5267/3731087271.py in <cell line: 0>()
#       1 name="python"
# ----> 2 print(neme1)
#
# NameError: name 'neme1' is not defined

# %%
with open("kamal.txt","w")as f:
  f.write("python programming language file handling concept and IOError")
  f.close()

# %%
with open("kamal.txt","r")as f:
  print(f.read())
  f.close()
# Out:
# python programming language file handling concept and IOError

# %%
with open("python.txt","r")as f:
  print(f.read())
  f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5267/3744954733.py in <cell line: 0>()
# ----> 1 with open("python.txt","r")as f:
#       2   print(f.read())
#       3   f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python.txt'

# %%
a=[1,2,3,4]
for i in a:
  print(i,end=" ")
# Out:
# 1 2 3 4

# %%
a=[1,2,3,4]
for i in a:
print(i)
# Out:
#   File "/tmp/ipykernel_5267/2549188212.py", line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
a=int(input("Enter a Number="))
b=a/0
print(b)
# Out:
# Enter a Number=4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_5267/1461338226.py in <cell line: 0>()
#       1 a=int(input("Enter a Number="))
# ----> 2 b=a/0
#       3 print(b)
#
# ZeroDivisionError: division by zero

# %%
try:
  a=int(input("Enter a Number="))
  b=a/0
  print(b)
except:
  print("Don't give 0 in denominator")
# Out:
# Enter a Number=4
# Don't give 0 in denominator

# %%
try:
  a=int(input("Enter a Number="))
  b=a/0
  print(b)
except Exception as f:
  print(f)
# Out:
# Enter a Number=4
# division by zero

# %%
try:
  a=int(input("Enter a Number="))
  b=a/0
  print(b)
except Exception as f:
  print(f)
# Out:
# Enter a Number=4
# division by zero

# %%
a=int(input("Enter a number="))
b=a/0
print(b)
# Out:
# Enter a number=4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_5267/2653635389.py in <cell line: 0>()
#       1 a=int(input("Enter a number="))
# ----> 2 b=a/0
#       3 print(b)
#
# ZeroDivisionError: division by zero

# %%
name="kamal"
print(namel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5267/3240693561.py in <cell line: 0>()
#       1 name="kamal"
# ----> 2 print(namel)
#
# NameError: name 'namel' is not defined

# %%
try:
  name="kamal"
  print(name1)
except NameError as f:
  print(f)
# Out:
# name 'name1' is not defined

# %%
try:
  name="kamal"
  print(name1)
except NameError as f:
  print(f)
else:
  print("I am Executing")
# Out:
# name 'name1' is not defined
# name 'name1' is not defined

# %%
a=input("enter a number=")
b=int(a)
print(b)
# Out:
# enter a number=k
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5267/791628155.py in <cell line: 0>()
#       1 a=input("enter a number=")
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'k'

# %%
try:
  a=input("Enter a Number=")
  b=int(a)
  print(b)
except Exception as f:
  print(f)
# Out:
# Enter a Number=4
# 4

# %%
num1=input("please enter a number")
try:
  num2=int(num1)
  print(num2)
except Exception as f:
  print(f)
  print("please enter the correct input")
print("outside of try-except clauses.This statement is always executed.")
# Out:
# please enter a numberl
# invalid literal for int() with base 10: 'l'
# please enter the correct input
# outside of try-except clauses.This statement is always executed.

# %%
num1=input("please enter a number")
try:
  num2=int(num1)
  print(num2)
except:
  pass
print("Outside of try- catch clauses.This statement is always executed.")
# Out:
# please enter a numberk
# Outside of try- catch clauses.This statement is always executed.
