# %%
print("python")
# Out:
# python

# %%
print("Hey")
# Out:
# Hey

# %%
print("""my name is  Rajath Kumar M.p I love python.""")
# Out:
# my name is  Rajath Kumar M.p I love python.

# %%
a=1
print("the value of a is:",a)
# Out:
# the value of a is: 1

# %%
me="kamal"
print("my name is",me)
# Out:
# my name is kamal

# %%
st1="world"
print("Hello",st1)

st2= !
print('hello',st1,st2)
# Out:
# Hello world
# hello world []

# %%
x=23
print("age is:",x)
# Out:
# age is: 23

# %%
print("hello",st1,st2)
# Out:
# hello world []

# %%
s1="sunday"
t1="10:45 am"

# %%
print("today is",s1,"time is",t1)
# Out:
# today is sunday time is 10:45 am

# %%
a="data science"
b="machine learning"
print("python can do both"+" "+a+" and time is "+t1)
# Out:
# python can do both data science and time is 10:45 am

# %%
print("today is"+" "+s1+" and time is "+t1)
# Out:
# today is sunday and time is 10:45 am

# %%
a="machine learning"
b="2"
year="2021"

# %%
print("welcome to",b,"class of ",a,"in the year ",year)
# Out:
# welcome to 2 class of  machine learning in the year  2021

# %%
print("welcome to "+" "+ b+"class of "+a+" "+"in the year "+year)
# Out:
# welcome to  2class of machine learning in the year 2021

# %%
a="machine learning"
b="2"
year="2021"

# %%
print(type(a),type(b),type(year))
# Out:
# <class 'str'> <class 'str'> <class 'str'>

# %%
a
# Out:
# 'machine learning'

# %%
print("welcome to the class %s of data science"%a)
# Out:
# welcome to the class machine learning of data science

# %%
a=1
print("the value is=%d"%a)
# Out:
# the value is=1

# %%
print("welcome to %s"%a)
# Out:
# welcome to 1

# %%
a="python"
b="data science"
c="artificial intelligence"
d="machine learning"
print("%s is programming language used to work on %s and %s is an heart for %s"%(a,b,c,b))
# Out:
# python is programming language used to work on data science and artificial intelligence is an heart for data science

# %%
a=1
b=12.2
c="python"
print("the value of a is %d and value of b is %f and text of c is %s"%(a,b,c))
# Out:
# the value of a is 1 and value of b is 12.200000 and text of c is python

# %%
a=1
b=12.2
c="python"
print("the value of a is %d and value of b is %f and text of c is %s"%(c,a,b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7745/529043401.py in <cell line: 0>()
#       2 b=12.2
#       3 c="python"
# ----> 4 print("the value of a is %d and value of b is %f and text of c is %s"%(c,a,b))
#
# TypeError: %d format: a real number is required, not str

# %%
print("welcome to the %d class of %s in %d"%(a,st2,year))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7745/4135506151.py in <cell line: 0>()
# ----> 1 print("welcome to the %d class of %s in %d"%(a,st2,year))
#
# TypeError: %d format: a real number is required, not str

# %%
a="1"
b="12.2"
c="python"
print("the value of a is",a,"the value of b is",b,"the text of c is",c)
print("the value of a is "+a+" the value of b is "+b+" the text of c is "+c)
print("the value of a is %s the value of b is %s the text of c is %s"%(a,b,c))
# Out:
# the value of a is 1 the value of b is 12.2 the text of c is python
# the value of a is 1 the value of b is 12.2 the text of c is python
# the value of a is 1 the value of b is 12.2 the text of c is python

# %%
print("hello %s"%st1)
# Out:
# hello world

# %%
print("hello %s %s"%(st1,st2))
# Out:
# hello world []

# %%
print(2*10)
# Out:
# 20

# %%
print("2"*10)
# Out:
# 2222222222

# %%
print("python \nData \nScience")
# Out:
# python
# Data
# Science

# %%
print("\\n")
# Out:
# \n

# %%
print("jan\nfeb\nmar\napr\nmay\njun\njul\naug\nsep\noct\nnov\ndec")
# Out:
# jan
# feb
# mar
# apr
# may
# jun
# jul
# aug
# sep
# oct
# nov
# dec

# %%
print("i want \\n to be printed.")
# Out:
# i want \n to be printed.

# %%
print("python\t data\t science")
# Out:
# python	 data	 science

# %%
print("""
Routine:
\t-Eat
\t-sleep\n\t-repeat
""")
# Out:
# Routine:
# 	-Eat
# 	-sleep
# 	-repeat

# %%
10/5
# Out:
# 2.0

# %%
pie=22/7

# %%
pie
# Out:
# 3.142857142857143

# %%
print("value of pie is",pie)
# Out:
# value of pie is 3.142857142857143

# %%
print("value of pie is %.3f"%pie)
# Out:
# value of pie is 3.143

# %%
"%.2f"%3.121312312312
# Out:
# '3.12'
