# %%
_&=1
print(_&)
# Out:
#   File "/tmp/ipykernel_6717/407033180.py", line 2
#     print(_&)
#             ^
# SyntaxError: invalid syntax

# %%
&="kamal"
print(&)
# Out:
#   File "/tmp/ipykernel_6717/2541048633.py", line 1
#     &="kamal"
#     ^
# SyntaxError: invalid syntax

# %%
13="data science"
print(13)
# Out:
#   File "/tmp/ipykernel_6717/1538770380.py", line 1
#     13="data science"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a="python"
print(a)
# Out:
# python

# %%
_9lives="python"
print(_9lives)
# Out:
# python

# %%
a=32.2
print(a)
# Out:
# 32.2

# %%
a="kamal"
print(a)
# Out:
# kamal

# %%
_123="python"
print(_123)
# Out:
# python

# %%
course123="data science"
print(course123)
# Out:
# data science

# %%
9lives=9
# Out:
#   File "/tmp/ipykernel_6717/2105786789.py", line 1
#     9lives=9
#     ^
# SyntaxError: invalid decimal literal

# %%
a=1
print(a)
type(a)
# Out:
# 1
# int

# %%
b=1.2
print(b)
type(b)
# Out:
# 1.2
# float

# %%
c="python"
print(c)
type(c)
# Out:
# python
# str

# %%
a=1
b=12.2
c="python"
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# 1 12.2 python
# <class 'int'> <class 'float'> <class 'str'>

# %%
a=1
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6717/1939438031.py in <cell line: 0>()
#       1 a=1
# ----> 2 print(A)
#
# NameError: name 'A' is not defined

# %%
a=12
b=12
print(a)
print(b)
# Out:
# 12
# 12

# %%
a=12
b=a
print(b)
# Out:
# 12

# %%
name="Ayushi"
print(NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6717/1462650481.py in <cell line: 0>()
#       1 name="Ayushi"
# ----> 2 print(NAME)
#
# NameError: name 'NAME' is not defined

# %%
name
# Out:
# 'Ayushi'

# %%
age=7
print(age)
# Out:
# 7

# %%
x=y=z="python"
print(x)
print(y)
print(z)
# Out:
# python
# python
# python

# %%
a,b,c=1,2,3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c="latha",12.2,4

# %%
print(a,b,c)
# Out:
# latha 12.2 4

# %%
age="Dinosaur"
print(age)
# Out:
# Dinosaur

# %%
7=age
# Out:
#   File "/tmp/ipykernel_6717/2936287762.py", line 1
#     7=age
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
False=choice
# Out:
#   File "/tmp/ipykernel_6717/3844524471.py", line 1
#     False=choice
#     ^
# SyntaxError: cannot assign to False

# %%
age,city=24,"hyd"
print(age,city)
# Out:
# 24 hyd

# %%
age=fav=7
print(age,fav)
# Out:
# 7 7

# %%
a,b="red","blue"
a,b=b,a
print(a,b)
# Out:
# blue red

# %%
a="red"
del a
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6717/2242617191.py in <cell line: 0>()
#       1 a="red"
#       2 del a
# ----> 3 a
#
# NameError: name 'a' is not defined

# %%
car="BMW"
Car="Mercedes"
CAR="jaguar"
print(car)
print(Car)
print(CAR)
# Out:
# BMW
# Mercedes
# jaguar
